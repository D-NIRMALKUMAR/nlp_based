# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Example text data
sentences = [
    'I love machine learning',
    'I love deep learning',
    'Deep learning is fun',
    'Machine learning is powerful',
    'nirmal kumar',
    'nirmal raj',
    'nirmal sekar'
]

# Tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
total_words = len(tokenizer.word_index) + 1

# Convert text to sequences
sequences = tokenizer.texts_to_sequences(sentences)

# Create input sequences and labels
input_sequences = []
for seq in sequences:
    for i in range(1, len(seq)):
        n_gram_sequence = seq[:i+1]
        input_sequences.append(n_gram_sequence)

# Pad sequences
max_sequence_length = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# %%
# Define model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(total_words, 50, input_length=max_sequence_length - 1),
    tf.keras.layers.SimpleRNN(50),
    tf.keras.layers.Dense(total_words, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
import numpy as np

X, y = [], []
for seq in input_sequences:
    X.append(seq[:-1])
    y.append(seq[-1])

X = np.array(X)
y = np.array(y)

# Train the model
model.fit(X, y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.0667 - loss: 2.5827
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.1333 - loss: 2.5597
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.1333 - loss: 2.5369
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.2000 - loss: 2.5142
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.3333 - loss: 2.4914
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.4000 - loss: 2.4685
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.5333 - loss: 2.4453
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6000 - loss: 2.4216
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.6000 - loss: 2.3974
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.6667 - loss: 2.3725
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.6667 - loss: 2.3468
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.6667 - loss: 2.3201
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6667 - loss: 2.2925
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.6667 - loss: 2.2639
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.6667 - loss: 2.2341
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.6667 - loss: 2.2030
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.6667 - loss: 2.1708
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.6667 - loss: 2.1372
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.6667 - loss: 2.1024
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.6667 - loss: 2.0663
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.6667 - loss: 2.0289
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.6667 - loss: 1.9903
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.5333 - loss: 1.9505
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.5333 - loss: 1.9098
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.5333 - loss: 1.8681
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.5333 - loss: 1.8257
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.5333 - loss: 1.7827
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.5333 - loss: 1.7393
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5333 - loss: 1.6958
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.5333 - loss: 1.6523
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.5333 - loss: 1.6092
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.5333 - loss: 1.5665
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.5333 - loss: 1.5245
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6667 - loss: 1.4834
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6667 - loss: 1.4433
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.6667 - loss: 1.4042
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.6667 - loss: 1.3662
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.6667 - loss: 1.3294
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.6667 - loss: 1.2937
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.6667 - loss: 1.2592
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.6667 - loss: 1.2257
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - accuracy: 0.7333 - loss: 1.1933
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7333 - loss: 1.1619
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7333 - loss: 1.1315
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.7333 - loss: 1.1021
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.7333 - loss: 1.0737
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7333 - loss: 1.0462
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7333 - loss: 1.0197
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7333 - loss: 0.9942
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.7333 - loss: 0.9696
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.7333 - loss: 0.9458
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.7333 - loss: 0.9229
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7333 - loss: 0.9008
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.7333 - loss: 0.8794
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7333 - loss: 0.8587
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.7333 - loss: 0.8387
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.7333 - loss: 0.8193
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.7333 - loss: 0.8005
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.7333 - loss: 0.7823
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.7333 - loss: 0.7647
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7333 - loss: 0.7476
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7333 - loss: 0.7310
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.7333 - loss: 0.7149
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.7333 - loss: 0.6994
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.7333 - loss: 0.6843
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8000 - loss: 0.6698
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8000 - loss: 0.6557
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8000 - loss: 0.6421
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8000 - loss: 0.6289
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.8000 - loss: 0.6162
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8000 - loss: 0.6040
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.8000 - loss: 0.5922
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8000 - loss: 0.5808
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.8000 - loss: 0.5699
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.8000 - loss: 0.5594
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8000 - loss: 0.5493
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8000 - loss: 0.5396
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8000 - loss: 0.5303
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8000 - loss: 0.5213
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.8000 - loss: 0.5128
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.8000 - loss: 0.5045
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8000 - loss: 0.4966
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8000 - loss: 0.4891
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.8000 - loss: 0.4818
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.8000 - loss: 0.4749
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.8000 - loss: 0.4683
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8000 - loss: 0.4620
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8000 - loss: 0.4559
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8000 - loss: 0.4501
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8000 - loss: 0.4446
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8000 - loss: 0.4394
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8000 - loss: 0.4343
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8000 - loss: 0.4295
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8000 - loss: 0.4250
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8000 - loss: 0.4206
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8000 - loss: 0.4165
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8000 - loss: 0.4125
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8000 - loss: 0.4088
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8000 - loss: 0.4052
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8000 - loss: 0.4018

# %%
def predict_next_word(model, tokenizer, text):
    token_list = tokenizer.texts_to_sequences([text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_length-1, padding='pre')
    predicted_probs = model.predict(token_list, verbose=0)
    predicted_word_index = np.argmax(predicted_probs, axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    return predicted_word

# Example usage
input_text = "nirmal"
next_word = predict_next_word(model, tokenizer, input_text)
print(f"Next word prediction: {next_word}")
# Out:
# Next word prediction: sekar

# %%
'''Natural Language Processing (NLP) has a wide range of applications across various domains. Here are some key areas where NLP is commonly used:

1. **Search Engines**: NLP helps improve search engine algorithms by understanding user queries and retrieving relevant information. It aids in semantic search, query expansion, and ranking of search results.

2. **Machine Translation**: Tools like Google Translate use NLP to translate text from one language to another, making communication across different languages more accessible.

3. **Sentiment Analysis**: Businesses and organizations use NLP to analyze customer feedback, reviews, and social media posts to gauge public sentiment and improve products or services.

4. **Chatbots and Virtual Assistants**: NLP powers conversational agents like Siri, Alexa, and chatbots on customer service websites, enabling them to understand and respond to user inquiries in natural language.

5. **Text Classification**: NLP is used to categorize text into predefined labels, such as spam detection in emails, topic categorization in news articles, or sentiment classification in social media posts.

6. **Named Entity Recognition (NER)**: This involves identifying and classifying entities like names of people, organizations, dates, and locations within a text, which is useful in information extraction and knowledge management.

7. **Speech Recognition and Synthesis**: NLP enables voice recognition systems to convert spoken language into text (speech-to-text) and generate spoken language from text (text-to-speech), which is useful in voice-activated assistants and accessibility tools.

8. **Information Extraction**: NLP techniques are used to extract structured information from unstructured text, such as identifying key phrases, relationships, and facts in documents.

9. **Text Generation**: Applications like automatic content generation, creative writing assistants, and summarization tools use NLP to produce coherent and contextually relevant text based on given inputs.

10. **Document Summarization**: NLP algorithms can create concise summaries of long documents, helping users quickly understand the main points without reading the entire text.

11. **Question Answering Systems**: These systems use NLP to provide accurate answers to user questions by retrieving and understanding information from various sources.

12. **Language Modeling**: NLP is used to build models that predict the next word or phrase in a sentence, which is fundamental for many applications, including autocomplete and text prediction.

13. **Text-to-Speech (TTS)**: NLP helps convert written text into spoken words, making content more accessible for visually impaired individuals and enhancing user experiences in various applications.

14. **Personalization**: By analyzing user interactions and preferences, NLP helps personalize content, recommendations, and advertisements based on individual behavior and interests.

15. **Healthcare**: NLP is used for analyzing medical records, extracting relevant information from clinical notes, and assisting in diagnostics by interpreting patient data and research literature.

These are just a few examples, and the field of NLP is continually evolving, leading to new applications and advancements.'''
# Out:
# 'Natural Language Processing (NLP) has a wide range of applications across various domains. Here are some key areas where NLP is commonly used:\n\n1. **Search Engines**: NLP helps improve search engine algorithms by understanding user queries and retrieving relevant information. It aids in semantic search, query expansion, and ranking of search results.\n\n2. **Machine Translation**: Tools like Google Translate use NLP to translate text from one language to another, making communication across different languages more accessible.\n\n3. **Sentiment Analysis**: Businesses and organizations use NLP to analyze customer feedback, reviews, and social media posts to gauge public sentiment and improve products or services.\n\n4. **Chatbots and Virtual Assistants**: NLP powers conversational agents like Siri, Alexa, and chatbots on customer service websites, enabling them to understand and respond to user inquiries in natural language.\n\n5. **Text Classification**: NLP is used to categorize text into predefined labels, such as spam detection in emails, topic categorization in news articles, or sentiment classification in social media posts.\n\n6. **Named Entity Recognition (NER)**: This involves identifying and classifying entities like names of people, organizations, dates, and locations within a text, which is useful in information extraction and knowledge management.\n\n7. **Speech Recognition and Synthesis**: NLP enables voice recognition systems to convert spoken language into text (speech-to-text) and generate spoken language from text (text-to-speech), which is useful in voice-activated assistants and accessibility tools.\n\n8. **Information Extraction**: NLP techniques are used to extract structured information from unstructured text, such as identifying key phrases, relationships, and facts in documents.\n\n9. **Text Generation**: Applications like automatic content generation, creative writing assistants, and summarization tools use NLP to produce coherent and contextually relevant text based on given inputs.\n\n10. **Document Summarization**: NLP algorithms can create concise summaries of long documents, helping users quickly understand the main points without reading the entire text.\n\n11. **Question Answering Systems**: These systems use NLP to provide accurate answers to user questions by retrieving and understanding information from various sources.\n\n12. **Language Modeling**: NLP is used to build models that predict the next word or phrase in a sentence, which is fundamental for many applications, including autocomplete and text prediction.\n\n13. **Text-to-Speech (TTS)**: NLP helps convert written text into spoken words, making content more accessible for visually impaired individuals and enhancing user experiences in various applications.\n\n14. **Personalization**: By analyzing user interactions and preferences, NLP helps personalize content, recommendations, and advertisements based on individual behavior and interests.\n\n15. **Healthcare**: NLP is used for analyzing medical records, extracting relevant information from clinical notes, and assisting in diagnostics by interpreting patient data and research literature.\n\nThese are just a few examples, and the field of NLP is continually evolving, leading to new applications and advancements.'
